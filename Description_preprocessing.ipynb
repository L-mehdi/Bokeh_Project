# %% [markdown]
# # Description et Prétraitement des Données

# %% [markdown]
# Ce notebook contient la description et le prétraitement du dataset marocain fourni. Nous utiliserons les bibliothèques Pandas et NumPy pour explorer et préparer les données.

# %% [markdown]
# ## Description des données

# %% [markdown]
# Imorter les bibliothèques nécessaires

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Lire le fichier

# %%
df = pd.read_parquet('Date_final_dataset_balanced_float32.parquet')

# %% [markdown]
# Afficher les informations du dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934586 entries, 0 to 934585
# Columns: 278 entries, acq_date to is_fire
# dtypes: datetime64[ns](1), float32(277)
# memory usage: 994.7 MB

# %% [markdown]
# Afficher un aperçu du dataset

# %%
df.head()
# Out:
#     acq_date   latitude  longitude  is_holiday  day_of_week  day_of_year  \
# 0 2015-05-28  31.390602  -4.254445         0.0          3.0        148.0
# 1 2017-12-05  33.832943  -5.188356         0.0          1.0        339.0
# 2 2021-11-19  35.385689  -5.684218         0.0          4.0        323.0
# 3 2014-04-19  30.122351  -7.498038         0.0          5.0        109.0
# 4 2014-04-11  30.221554  -9.154314         0.0          4.0        101.0
#
#    is_weekend    NDVI  SoilMoisture   sea_distance  ...  \
# 0         0.0  1139.0           7.0  464731.937500  ...
# 1         0.0  3223.0          31.0  186799.984375  ...
# 2         0.0  4987.0          30.0   44937.300781  ...
# 3         1.0   991.0          12.5  231336.125000  ...
# 4         0.0  2171.0          18.0   51333.945312  ...
#
#    wind_gust_quarterly_mean  dew_point_quarterly_mean  \
# 0                882.085571                 27.641111
# 1                936.817383                 52.452175
# ...

# %% [markdown]
# Afficher les statistiques descriptives du dataset

# %%
df.describe()
# Out:
#                             acq_date       latitude      longitude  \
# count                         934586  934586.000000  934586.000000
# mean   2018-02-11 14:49:51.211081472      32.793350      -6.055579
# min              2013-01-31 00:00:00      27.074949     -12.044235
# 25%              2015-09-16 00:00:00      31.421812      -7.749783
# 50%              2018-03-10 00:00:00      33.368835      -5.626343
# 75%              2020-08-18 00:00:00      34.670555      -4.479708
# max              2022-12-23 00:00:00      35.915291      -1.656559
# std                              NaN       2.302324       2.398227
#
#           is_holiday    day_of_week    day_of_year     is_weekend  \
# count  934586.000000  934586.000000  934586.000000  934586.000000
# mean        0.062526       2.976634     194.607834       0.282150
# min         0.000000       0.000000       1.000000       0.000000
# 25%         0.000000       1.000000     121.000000       0.000000
# ...

# %% [markdown]
# Le dataset contient les colonnes suivantes :
# - Marqueurs temporels : acq_date, day_of_week, day_of_year et les indicateurs liés aux jours fériés (is_holiday, is_weekend).
# - Caractéristiques spatiales : latitude, longitude et sea_distance.
# - Conditions environnementales : NDVI pour la santé de la végétation et SoilMoisture.
# - Données météorologiques : average_temperature, maximum_temperature, minimum_temperature, precipitation, snow_depth, wind_speed et plus encore.
# - Statistiques météorologiques agrégées : périodes hebdomadaires, mensuelles, trimestrielles et annuelles.
# - Variable de résultat : is_fire indique la présence (1) ou l'absence (0) d'un incendie de forêt.
#
# Ce dataset a été choisi en raison de sa nature complète, intégrant des données météorologiques, environnementales et spatiales pour faciliter la prédiction précise des incendies de forêt.

# %% [markdown]
# ## Prétraitement des Données

# %% [markdown]
# Gestion des valeurs manquantes

# %%
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
missing_values.sort_values(ascending=False, inplace=True)
missing_values
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Remplir les valeurs manquantes avec la moyenne de chaque colonne

# %%
df.fillna(df.mean(), inplace=True)

# %% [markdown]
# Vérifier à nouveau les valeurs manquantes

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Normalisation des Données

# %% [markdown]
# Nous allons normaliser certaines colonnes pour faciliter l'analyse.

# %% [markdown]
# Normaliser les colonnes sélectionnées

# %%
columns_to_normalize = ['NDVI', 'SoilMoisture', 'average_temperature_yearly_mean', 'maximum_temperature_yearly_mean', 'minimum_temperature_yearly_mean', 'precipitation_yearly_mean']
df[columns_to_normalize] = (df[columns_to_normalize] - df[columns_to_normalize].min()) / (df[columns_to_normalize].max() - df[columns_to_normalize].min())

# %% [markdown]
# Afficher un aperçu des données normalisées

# %%
df.head()
# Out:
#     acq_date   latitude  longitude  is_holiday  day_of_week  day_of_year  \
# 0 2015-05-28  31.390602  -4.254445         0.0          3.0        148.0
# 1 2017-12-05  33.832943  -5.188356         0.0          1.0        339.0
# 2 2021-11-19  35.385689  -5.684218         0.0          4.0        323.0
# 3 2014-04-19  30.122351  -7.498038         0.0          5.0        109.0
# 4 2014-04-11  30.221554  -9.154314         0.0          4.0        101.0
#
#    is_weekend      NDVI  SoilMoisture   sea_distance  ...  \
# 0         0.0  0.207024      0.070707  464731.937500  ...
# 1         0.0  0.433620      0.313131  186799.984375  ...
# 2         0.0  0.625421      0.303030   44937.300781  ...
# 3         1.0  0.190932      0.126263  231336.125000  ...
# 4         0.0  0.319235      0.181818   51333.945312  ...
#
#    wind_gust_quarterly_mean  dew_point_quarterly_mean  \
# 0                882.085571                 27.641111
# 1                936.817383                 52.452175
# ...
